# %% [markdown]
# # Descripcion
# Papemill es un paquete de python que permito reproducir de manera automática jupyer notebooks.  Solo se necesita especificar una serie de parametros.  Se crea un jupyter notebook "plantilla", el cual se corre una vez, y luego desde la terminal, un código python, u otro jupyter notebook se corre la herramienta, y se genera un nuevo fichero jupyter notebook por parámetro sobre el cual hayamos querido iterar.  Aquí usaremos la opción del jupyter notebook, e iteraremos sobre el año en que tenemos datos de satélite de temperatura (como en los tutoriales anterirores).
#
# Pueden leer más sobre esta herramienta aquí:
# * https://papermill.readthedocs.io/en/latest/
# * https://papermill.readthedocs.io/en/latest/usage-execute.html
# * https://medium.com/y-data-stories/automating-jupyter-notebooks-with-papermill-4b8543ece92f

# %% [markdown]
# # Parametros:

# %%
dominio = [-85., -50., -20., -2.] #'Golfo de Mexico' lon_min, lon_max, lat_min, lat_max
zona = 'Frente a Peru'
nombre_salida = "TEMPLATE_espacial"

# %%
print('Zona: ', zona)
print('Dominio: ', dominio)
# Out:
# Zona:  Frente a Peru
# Dominio:  [-85.0, -50.0, -20.0, -2.0]

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

import matplotlib
import matplotlib.gridspec as gridspec
import numpy as np
import glob
from collections import Counter
from netCDF4 import Dataset

import cmocean as cmo

# %%
# fichero = '../../../shared-readwrite/ERA5/ERA5_Coarse.nc' ## 
fichero = '/home/jovyan/shared/datos_para_tutoriales/Talleres_intermedios/7-Octubre-2025/datos_espaciales_python/20251004120000-REMSS-L4_GHRSST-SSTfnd-MW_IR_OI-GLOB-v02.0-fv05.1.nc'

# %%
fileobj = xr.open_dataset(fichero) # importando el archivo
sst = fileobj['analysed_sst'][:] # Leyendo las variables del archivo, como dijimos, un nombre auto-explicativo
sst = sst - 273.15 # convertiendo a Celsius de Kelvin

# %% [markdown]
# ## Seleccionamos los datos de la zona especificada:

# %% [markdown]
# ## Nuestra zona al completo:

# %%
sst.plot()

# %% [markdown]
# ## Nuestra zona seleccionada:

# %%
sst_sel = sst.where((sst.lon > dominio[0]) & 
                    (sst.lon < dominio[1]) &
                    (sst.lat > dominio[2]) &
                    (sst.lat < dominio[3])
                   , drop = True); # El ";" es para que no se muestren los outputs de esta función

# %%
sst_sel
# Out:
# <xarray.DataArray 'analysed_sst' (time: 1, lat: 205, lon: 398)> Size: 326kB
# array([[[18.46231 , 18.43042 , 18.437988, ...,       nan,       nan,
#                nan],
#         [18.460632, 18.459808, 18.43042 , ...,       nan,       nan,
#                nan],
#         [18.480774, 18.451416, 18.434631, ...,       nan,       nan,
#                nan],
#         ...,
#         [20.941498, 20.782867, 20.715729, ...,       nan,       nan,
#                nan],
#         [21.004456, 20.836578, 20.76944 , ...,       nan,       nan,
#                nan],
#         [21.283081, 21.095917, 21.05481 , ...,       nan,       nan,
#                nan]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 820B -20.0 -19.91 -19.82 ... -2.241 -2.153 -2.065
#   * lon      (lon) float32 2kB -84.95 -84.86 -84.77 ... -50.23 -50.14 -50.05
#   * time     (time) datetime64[ns] 8B 2025-10-04T12:00:00

# %%
sst_sel = sst_sel.squeeze()

# %%
sst_sel
# Out:
# <xarray.DataArray 'analysed_sst' (lat: 159, lon: 171)> Size: 109kB
# array([[      nan,       nan,       nan, ..., 30.689484, 30.731445,
#         30.735657],
#        [      nan,       nan,       nan, ..., 30.62738 , 30.660126,
#         30.712158],
#        [      nan,       nan,       nan, ..., 30.620667, 30.667664,
#         30.66095 ],
#        ...,
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan]], dtype=float32)
# Coordinates:
#   * lat      (lat) float32 636B 18.06 18.15 18.24 18.33 ... 31.77 31.86 31.95
#   * lon      (lon) float32 684B -99.98 -99.89 -99.8 ... -85.21 -85.12 -85.03
#     time     datetime64[ns] 8B 2025-10-04T12:00:00

# %%
sst_sel.plot()

# %% [markdown]
# ## Graficamos los valores de temperatura para esa zona:

# %%
cmap = cmo.cm.thermal

# %%
fig, ax = plt.subplots()
image = plt.pcolormesh(sst_sel.lon, sst_sel.lat, sst_sel,cmap=cmap,
                  vmin=27,vmax=31)

cax = fig.add_axes([ax.get_position().x1+0.01,
                    ax.get_position().y0,0.02,
                    ax.get_position().height])
cbar= plt.colorbar(image, cax=cax)

plt.xlabel('Longitude (˚)')
plt.xlabel('Latitude (˚)')
cbar.set_label('SST (˚C)') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 image = plt.pcolormesh(sst_sel.lon, sst_sel.lat, sst_sel,cmap=cmap,
#       3                   vmin=27,vmax=31)
#       5 cax = fig.add_axes([ax.get_position().x1+0.01,
#       6                     ax.get_position().y0,0.02,
#       7                     ax.get_position().height])
#       8 cbar= plt.colorbar(image, cax=cax)
#
# File /home/.pixi/envs/default/lib/python3.12/site-packages/matplotlib/pyplot.py:3493, in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    3480 @_copy_docstring_and_deprecators(Axes.pcolormesh)
#    3481 def pcolormesh(
#    3482     *args: ArrayLike,
#    (...)
#    3491     **kwargs,
#    3492 ) -> QuadMesh:
# -> 3493     __ret = gca().pcolormesh(
#    3494         *args,
#    3495         alpha=alpha,
#    3496         norm=norm,
#    3497         cmap=cmap,
#    3498         vmin=vmin,
#    3499         vmax=vmax,
#    3500         shading=shading,
#    3501         antialiased=antialiased,
#    3502         **({"data": data} if data is not None else {}),
#    3503         **kwargs,
#    3504     )
#    3505     sci(__ret)
#    3506     return __ret
#
# File /home/.pixi/envs/default/lib/python3.12/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /home/.pixi/envs/default/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6292, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6289 shading = shading.lower()
#    6290 kwargs.setdefault('edgecolors', 'none')
# -> 6292 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6293                                     shading=shading, kwargs=kwargs)
#    6294 coords = np.stack([X, Y], axis=-1)
#    6296 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
#
# File /home/.pixi/envs/default/lib/python3.12/site-packages/matplotlib/axes/_axes.py:5839, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    5837 if shading == 'flat':
#    5838     if (Nx, Ny) != (ncols + 1, nrows + 1):
# -> 5839         raise TypeError(f"Dimensions of C {C.shape} should"
#    5840                         f" be one smaller than X({Nx}) and Y({Ny})"
#    5841                         f" while using shading='flat'"
#    5842                         f" see help({funcname})")
#    5843 else:    # ['nearest', 'gouraud']:
#    5844     if (Nx, Ny) != (ncols, nrows):
#
# TypeError: Dimensions of C (1, 205, 398) should be one smaller than X(398) and Y(205) while using shading='flat' see help(pcolormesh)

# %% [markdown]
# ## Calculamos y visualizamos ahora la anomalía de SST:

# %% [markdown]
# ### En este caso solo quitaremos una media espacial:

# %%
print('La media de SST en el día ' + str(sst_sel.time.values)[0:10] + ' para esta zona fue:', sst_sel.mean().values, '˚C')
# Out:
# La media de SST en el día 2025-10-04 para esta zona fue: 29.592548 ˚C

# %%
print('La anomalía de SST en el día ' + str(sst_sel.time.values)[0:10] + ' para esta zona fue:')
# Out:
# La anomalía de SST en el día 2025-10-04 para esta zona fue:

# %%
fig, ax = plt.subplots()
image = plt.pcolormesh(sst_sel.lon, sst_sel.lat, sst_sel - sst_sel.mean(), cmap='RdBu_r',
                  vmin=-1.5, vmax=1.5)

cax = fig.add_axes([ax.get_position().x1+0.01,
                    ax.get_position().y0,0.02,
                    ax.get_position().height])

cbar= plt.colorbar(image, cax=cax)
cbar.set_label('Anomalía de SST (˚C)') 
plt.show()

# %%
import subprocess

# Construimos el comando nbconvert usando el parámetro: nombre_entrada
command = f'jupyter nbconvert --to html --no-input {nombre_salida}.ipynb --output {nombre_salida}.html'

# Ejecutamos el comando
subprocess.run(command, shell=True, check=True)

# Cualquier fichero exisitente previamente se sobreescribirá con el nuevo generado aquí.
# Out:
# [NbConvertApp] Converting notebook TEMPLATE_espacial.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 355223 bytes to TEMPLATE_espacial.html
# CompletedProcess(args='jupyter nbconvert --to html --no-input TEMPLATE_espacial.ipynb --output TEMPLATE_espacial.html', returncode=0)

# %% [markdown]
# # Ejercicio:
# Probar de ahora crear un fichero papermill, y generar este notebook para otras zonas Latinoamericanas
